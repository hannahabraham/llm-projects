# %%
import tiktoken

encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")
tokens = encoding.encode("Hi, My name is Hannah and I like coconut icecream")

# %%
for token in tokens:
    token_text =encoding.decode([token])
    print(f"{token} = {token_text}")
# Out:
# 13347 = Hi
# 11 = ,
# 3092 =  My
# 836 =  name
# 374 =  is
# 48361 =  Hannah
# 323 =  and
# 358 =  I
# 1093 =  like
# 34557 =  coconut
# 10054 =  ice
# 47100 = cream
